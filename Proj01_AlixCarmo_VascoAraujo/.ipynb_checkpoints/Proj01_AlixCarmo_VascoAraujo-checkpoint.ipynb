# %% [markdown]
# # Projeto 01 - Regressão aplicada à esperança média de vida

# %% [markdown]
# <b>Unidade Curricular:</b>  Aprendizagem Computacional </br>
# <b>Nome:</b> Alix Carmo
# <b>Nº:</b> 23324</br>
# <b>Nome:</b> Vasco Araújo
# <b>Nº:</b> 23055</br>

# %% [markdown]
# Este projeto propõe-se a desvendar os segredos por trás da expectativa de vida, utilizando alguns métodos de regressão. Ao explorar um conjunto de dados abrangente, será direcionado o foco para os parâmetros socioeconômicos, a fim de compreender a sua influência na longevidade global.
#
# A abordagem inicial envolve uma minuciosa Exploratory Data Analysis (EDA), fornecendo uma visão holística dos dados. Em seguida, serão aplicados alguns algoritmos de regressão, explorando suas nuances na previsão da expectativa de vida. A divisão do conjunto de dados em conjuntos de treino e teste permitirá validar e comparar o desempenho dos modelos.

# %% [markdown]
# No código abaixo temos os imports das bibliotecas utilizadas no desenvolvimento do projeto. Este projeto utiliza bibliotecas, como pandas, numpy, matplotlib, seaborn, sklearn.preprocessing, sklearn.linear_model, sklearn.metrics e sklearn.model_selection, para conduzir análise exploratória e modelagem preditiva. Essas ferramentas são cruciais para manipulação eficiente de dados, visualizações, pré-processamento, implementação de modelos de regressão linear, avaliação de desempenho e divisão de conjuntos de dados. O uso de itertools, StandardScaler e PolynomialFeatures complementa essas bibliotecas, proporcionando iterações eficientes, escalonamento de recursos e expansão de características polinomiais, respectivamente, contribuindo para uma análise abrangente da expectativa de vida com base em parâmetros socioeconômicos.

# %%
# import
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import itertools
import seaborn as sns
from sklearn.preprocessing import StandardScaler, PolynomialFeatures

# %% [markdown]
# No código abaixo é utilizada a biblioteca pandas para ler um arquivo CSV contendo os dados. O dataset é carregado na variável df, e as primeiras 9 linhas são exibidas usando o método head().

# %%
df = pd.read_csv("./datasets/Life Expectancy Data.csv")

df.head(9)
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
# 5  Afghanistan  2010  Developing              58.8            279.0
# 6  Afghanistan  2009  Developing              58.6            281.0
# 7  Afghanistan  2008  Developing              58.1            287.0
# 8  Afghanistan  2007  Developing              57.5            295.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# ...

# %% [markdown]
# ## Análise Exploratória dos Dados (EDA)

# %% [markdown]
# O código abaixo fornece uma visão rápida do conjunto de dados através de uma Análise Exploratória de Dados (EDA). Ele destaca o número de registos e colunas, lista os nomes das colunas, identifica valores nulos em cada coluna, esta identificação e a forma como se lidam com esses dados é crucial para garantir a integridade e a confiabilidade dos resultados. Por fim, são apresentadas estatísticas descritivas para a variável 'Life expectancy', é  importante observar que essa análise estatística pode ser estendida para outras colunas do conjunto de dados, permitindo uma compreensão mais abrangente das variáveis numéricas disponíveis. Essa análise inicial é fundamental para compreender a estrutura e a qualidade dos dados, orientando as próximas etapas na análise e modelagem preditiva.

# %%
#número de linhas e colunas
print("Número de Registos :",df.shape[0])
print("Número de colunas :",df.shape[1])
#lista com os nomes das colunas
print("\nColunas :",df.columns.tolist())
#registos NaN em cada coluna
print("\nRegistos NaN por coluna:\n", df.isnull().sum())
#obter estatísticas descritivas neste caso para a coluna 'Life expectancy '
#o mesmo pode ser aplicado para as outras colunas especialmente as númericas
print("\nEstatísticas Descritivas :",df.describe()['Life expectancy '])
# Out:
# Número de Registos : 2938
# Número de colunas : 22
#
# Colunas : ['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality', 'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B', 'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure', 'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population', ' thinness  1-19 years', ' thinness 5-9 years', 'Income composition of resources', 'Schooling']
#
# Registos NaN por coluna:
#  Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# ...

# %% [markdown]
# O código abaixo utiliza a biblioteca seaborn para criar um mapa de calor que visualiza a correlação entre as variáveis do conjunto de dados. O mapa de calor destaca padrões e relações, indicados por tons de cores. Valores próximos a 1 representam correlação positiva, enquanto valores próximos a -1 indicam correlação negativa. Essa visualização é uma ferramenta eficaz na Análise Exploratória de Dados (EDA) para identificar conexões entre variáveis e compreender a estrutura do conjunto de dados.

# %%
#heat map
sns.set(font_scale=0.5)
sns.heatmap(df.corr(),annot=True,annot_kws={'size': 4})
sns.set(font_scale=1)

# %% [markdown]
# ## Transformação dos dados

# %% [markdown]
# O código abaixo realiza a transformação de variáveis categóricas em valores numéricos para preparar o conjunto de dados para modelagem preditiva. O LabelEncoder é usado para converter os países em valores numéricos, enquanto a coluna 'Status' é codificada como 1 para 'Developing' e 2 para 'Developed'. A substituição de valores ausentes por zero é aplicada para lidar com dados faltantes, ao vez de realizar esta substituição poderia ter sido realizado outro tipo de substituição, como por exemplo pelo o valor médio de cada coluna. Essa etapa é fundamental para garantir a compatibilidade com algoritmos de aprendizado de máquina. O DataFrame resultante exibe as primeiras 9 linhas após as transformações.

# %%
#transformação dos paises em valores númericos
label_encoder = preprocessing.LabelEncoder()
df['Country'] = label_encoder.fit_transform(df['Country'])

#transformação dos estados de desenvolvimento em valores númericos
numeric_var = {'Status': {'Developing':1, 'Developed':2}} 
df = df.replace(numeric_var)

#substitui os valores NaN por 0
df.fillna(0, inplace=True)

df.head(9)
# Out:
#    Country  Year  Status  Life expectancy   Adult Mortality  infant deaths  \
# 0        0  2015       1              65.0            263.0             62
# 1        0  2014       1              59.9            271.0             64
# 2        0  2013       1              59.9            268.0             66
# 3        0  2012       1              59.5            272.0             69
# 4        0  2011       1              59.2            275.0             71
# 5        0  2010       1              58.8            279.0             74
# 6        0  2009       1              58.6            281.0             77
# 7        0  2008       1              58.1            287.0             80
# 8        0  2007       1              57.5            295.0             82
#
#    Alcohol  percentage expenditure  Hepatitis B  Measles   ...  Polio  \
# 0     0.01               71.279624         65.0      1154  ...    6.0
# 1     0.01               73.523582         62.0       492  ...   58.0
# ...

# %% [markdown]
# ## Outliers

# %% [markdown]
# O código abaixo utiliza a técnica do Intervalo Interquartílico (IQR) para identificar e remover outliers na variável 'Life expectancy'. Os quartis 25 e 75 são calculados, e outliers são definidos como valores abaixo de q25 - 1.5 * IQR ou acima de q75 + 1.5 * IQR. O número de outliers é impresso, e esses valores atípicos são removidos do DataFrame. Essa abordagem é eficaz para eliminar pontos fora do padrão, contribuindo para uma análise mais robusta e modelos de machine learning mais precisos.

# %%
#Calculo do quartis 25 e 75
q25, q75 = np.percentile(df['Life expectancy '], [25, 75])
# calculo do distancia entre quartis
iqr = q75 - q25
#Determinar outliers
outliers_mask = (df['Life expectancy '] < (q25 - 1.5 * iqr)) | (df['Life expectancy '] > (q75 + 1.5 * iqr))
print("Número de outliers :", outliers_mask.sum())
# Remover outliers do DataFrame
df = df[~outliers_mask]
# Out:
# Número de outliers : 20

# %% [markdown]
# ## Simple Linear Regression

# %% [markdown]
# A função <b><i>'my_regression_function'</i></b> foi projetada para realizar análises de regressão linear simples, um método fundamental na regressão. Na regressão linear simples, procura-se estabelecer uma relação linear entre uma variável independente e uma variável dependente. A função prepara os dados, treina um modelo de regressão linear utilizando conjuntos de treino, e calcula métricas de desempenho como o Erro Quadrático Médio (RMSE) e o R2-Score (r²) para avaliar a qualidade do modelo.

# %%
def my_regression_function(datax, datay):
    # Converter para arrays numpy
    X = datax.values.reshape(-1, 1)
    y = datay.values.reshape(-1, 1)

    # Dividir os dados em conjuntos de treinamento e teste
    train_x, test_x, train_y, test_y = train_test_split(X, y, test_size=0.25, random_state = 42)

    # Treinar um modelo de regressão linear
    regr = linear_model.LinearRegression()
    regr.fit(train_x, train_y)

    # Coeficientes
    coeficiente = regr.coef_[0][0]  # Coeficiente
    intercepto = regr.intercept_[0]  # Intercepto

    # Previsões nos dados de teste
    test_y_pred = regr.predict(test_x)

    # Calcular RMSE e r2
    rmse = mean_squared_error(test_y, test_y_pred, squared=False)
    r2 = r2_score(test_y, test_y_pred)
    
    return regr, rmse, r2

# %%
# Encontrar o índice da coluna 'Adult Mortality'
Adult_Mortality_index = df.columns.get_loc('Adult Mortality')

# Usar .iloc para dividir o DataFrame do índice da coluna 'Adult Mortality' até o final
cdf = df.iloc[:, Adult_Mortality_index:]

cdf.head(9)
# Out:
#    Adult Mortality  infant deaths  Alcohol  percentage expenditure  \
# 0            263.0             62     0.01               71.279624
# 1            271.0             64     0.01               73.523582
# 2            268.0             66     0.01               73.219243
# 3            272.0             69     0.01               78.184215
# 4            275.0             71     0.01                7.097109
# 5            279.0             74     0.01               79.679367
# 6            281.0             77     0.01               56.762217
# 7            287.0             80     0.03               25.873925
# 8            295.0             82     0.02               10.910156
#
#    Hepatitis B  Measles    BMI   under-five deaths   Polio  Total expenditure  \
# 0         65.0      1154   19.1                  83    6.0               8.16
# 1         62.0       492   18.6                  86   58.0               8.18
# ...

# %% [markdown]
# O código abaixo procura a melhor variável preditora para a expectativa de vida utilizando Regressão Linear Simples (SLR). Itera através das colunas do DataFrame, treinando modelos e avaliando o desempenho com base em R2 e RMSE. O modelo com o melhor desempenho é então visualizado em um gráfico de dispersão. Esse procedimento é valioso para identificar a influência individual das variáveis independentes na expectativa de vida, simplificando a complexidade da análise multivariada.

# %%
target = df[['Life expectancy ']]
slr_bestR2 = float("-inf")
slr_bestRMSE = float("inf")
slr_bestRegr = None
slr_bestColumn = ""
for i in cdf.columns:
    regr, rmse, r2 = my_regression_function(cdf[[i]], target)
    if(slr_bestR2 < r2):
        slr_bestR2 = r2
        slr_bestRMSE = rmse
        slr_bestRegr = regr
        slr_bestColumn = i
print("Coluna :",slr_bestColumn)
print("R2 :",slr_bestR2)
print("RMSE :",slr_bestRMSE)
# Visualização do resultado
y_pred = slr_bestRegr.predict(cdf[slr_bestColumn].values.reshape(-1, 1))
plt.scatter(cdf[slr_bestColumn], target, color='blue')
plt.plot(cdf[slr_bestColumn], y_pred, '-r', linewidth=3)
plt.xlabel(slr_bestColumn)
plt.ylabel('Life expectancy')
plt.title(f'Simple Linear Regression')
plt.show()
# Out:
# Coluna : Adult Mortality
# R2 : 0.46155793735117
# RMSE : 6.941223208772039

# %% [markdown]
# ## Multiple Linear Regression

# %% [markdown]
# A função <b><i>'my_multiple_regression_function'</i></b> implementa uma análise de Regressão Linear Múltipla (MLR), que estende a Regressão Linear Simples para lidar com múltiplas variáveis independentes. O código divide os dados em conjuntos de treino e teste, treina um modelo MLR e avalia o seu desempenho com métricas como RMSE e r². A MLR é crucial quando há múltiplos fatores impactando a variável dependente, permitindo uma modelagem mais precisa e completa. Essa função oferece uma abordagem eficaz para análise e previsão em cenários mais complexos.

# %%
def my_multiple_regression_function(X,y):
    # Dividir os dados em conjuntos de treinamento e teste
    train_x, test_x, train_y, test_y = train_test_split(X, y, test_size=0.25, random_state = 42)

    # Treinar um modelo de regressão linear múltipla
    regr = linear_model.LinearRegression()
    regr.fit(train_x, train_y)

    # Previsões nos dados de teste
    test_y_pred = regr.predict(test_x)

    # Calculate RMSE and r2
    rmse = mean_squared_error(test_y, test_y_pred, squared=False)
    r2 = r2_score(test_y, test_y_pred)

    return regr, rmse, r2

# %% [markdown]
# O código abaixo realiza uma busca exaustiva por combinações de variáveis independentes para encontrar a melhor configuração em termos de R2-Score em uma Regressão Linear Múltipla (MLR). Iterando sobre diferentes números de variáveis, o modelo é treinado e avaliado para cada combinação. A melhor combinação é determinada com base no maior R2 encontrado. Esse método fornece uma abordagem sistemática para identificar as variáveis que melhor explicam a variabilidade na variável dependente.
# <br>
# <br>
# <b>NOTA :</b> O código abaixo encontra-se comentado pois demora muito tempo a correr

# %%
'''
# Obter as colunas do DataFrame
cdf_col_names = cdf.columns

# Inicializando as variáveis para armazenar os melhores resultados
mlr_bestR2 = float('-inf')
mlr_bestRMSE = float('inf')
mlr_bestCombination = None
mlr_bestRegr = None

# Iterando sobre todas as combinações de colunas, começando de 1 coluna até o número total de colunas
for i in range(1, len(cdf_col_names) + 1):
    for combo in itertools.combinations(cdf_col_names, i):
        # Selecionando a combinação atual de colunas para X
        dx = cdf[list(combo)].values
        
        # Chamando a função de regressão com o X atual e o alvo y
        regr, rmse, r2 = my_multiple_regression_function(dx, target)
        
        # Verificando se o R^2 atual é o melhor e atualizando os melhores valores e a combinação
        if r2 > mlr_bestR2: 
            mlr_bestR2 = r2 
            mlr_bestRMSE = rmse
            mlr_bestCombination = combo
            mlr_bestRegr = regr
            
# Imprimindo os resultados
print(f"Melhor R^2: {mlr_bestR2} com a combinação {mlr_bestCombination}")
'''
################################################################################
##################################### OUTPUT ###################################

# Melhor R^2: 0.7898230821287494 com a combinação ('Adult Mortality', 'infant deaths', 'Alcohol', 
#'percentage expenditure', 'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure', 
#'Diphtheria ', ' HIV/AIDS', 'GDP', ' thinness  1-19 years', 'Income composition of resources', 'Schooling')
# Out:
# '\n# Obter as colunas do DataFrame\ncdf_col_names = cdf.columns\n\n# Inicializando as variáveis para armazenar os melhores resultados\nmlr_bestR2 = float(\'-inf\')\nmlr_bestRMSE = float(\'inf\')\nmlr_bestCombination = None\nmlr_bestRegr = None\n\n# Iterando sobre todas as combinações de colunas, começando de 1 coluna até o número total de colunas\nfor i in range(1, len(cdf_col_names) + 1):\n    for combo in itertools.combinations(cdf_col_names, i):\n        # Selecionando a combinação atual de colunas para X\n        dx = cdf[list(combo)].values\n        \n        # Chamando a função de regressão com o X atual e o alvo y\n        regr, rmse, r2 = my_multiple_regression_function(dx, target)\n        \n        # Verificando se o R^2 atual é o melhor e atualizando os melhores valores e a combinação\n        if r2 > mlr_bestR2: \n            mlr_bestR2 = r2 \n            mlr_bestRMSE = rmse\n            mlr_bestCombination = combo\n            mlr_bestRegr = regr\n            \n# Imprimi
# ...

# %% [markdown]
# O código abaixo utiliza a função <b><i>'my_multiple_regression_function'</i></b> para determinar o melhor modelo encontrado na execução do código anterior. Este trecho de código só se encontra aqui para evitar ter de executar o código anterior.

# %%
# O melhor modelo de  regressão linear múltipla com o melhor R2, obtido do código anterior
mlr_bestCombo = df[['Adult Mortality', 'infant deaths', 'Alcohol', 'percentage expenditure', 
                    'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure', 
                    'Diphtheria ', ' HIV/AIDS', 'GDP', ' thinness  1-19 years', 
                    'Income composition of resources', 'Schooling']]

mlr_bestRegr, mlr_bestRMSE, mlr_bestR2 = my_multiple_regression_function(mlr_bestCombo, target)

print("RMSE :",mlr_bestRMSE)
print("R2-Score :",mlr_bestR2)
# Out:
# RMSE : 4.336696506365782
# R2-Score : 0.789823082128749

# %% [markdown]
# ## Mínimos Quadrados Ordinários (OLS)

# %% [markdown]
# A função <b><i>'MyREG_OLS'</i></b> implementa o método dos mínimos quadrados ordinários (OLS) para realizar regressão linear. Essa abordagem procura encontrar os parâmetros que minimizam a soma dos quadrados dos resíduos, permitindo estimar coeficientes em modelos lineares. A função inclui automaticamente o termo de intercepto na equação da reta. O OLS é fundamental na análise estatística, proporcionando uma ferramenta eficaz para modelar e compreender relações entre variáveis.

# %%
def MyREG_OLS(X, y):
    X_b = np.concatenate([np.ones((X.shape[0], 1)), X], axis=1)
    theta_est = np.linalg.inv(X_b.T.dot(X_b)).dot(X_b.T).dot(y)
    return theta_est

# %% [markdown]
# O código abaixo realiza a aplicação prática do método dos mínimos quadrados ordinários (OLS) no dataset, dividindo-o em conjuntos de treino e teste. Após treinar o modelo OLS com os dados de treinamento, são feitas previsões nos dados de teste. As métricas de desempenho, Erro Quadrático Médio (RMSE) e R2-Score, são então calculadas para avaliar a precisão do modelo. Este processo fornece uma visão prática da eficácia do modelo OLS em realizar previsões precisas no contexto específico do conjunto de dados em questão.

# %%
cdf = df.drop('Life expectancy ', axis=1)
target = df[['Life expectancy ']]

train_x, test_x, train_y, test_y = train_test_split(cdf, target, test_size=0.25, random_state = 42)

ols_thetas = MyREG_OLS(train_x, train_y)
X_b = np.concatenate([np.ones((test_x.shape[0], 1)), test_x], axis=1)
ols_y_pred = X_b.dot(ols_thetas)

ols_rmse = mean_squared_error(test_y, ols_y_pred, squared=False)
ols_r2 = r2_score(test_y, ols_y_pred)

print("RMSE :",ols_rmse)
print("R2-Score :",ols_r2)
# Out:
# RMSE : 4.204635750033138
# R2-Score : 0.8024287643640795

# %% [markdown]
# ## Gradient Descent

# %% [markdown]
# O Gradient Descent é um algoritmo fundamental em machine learning usado para ajustar iterativamente os parâmetros do modelo e minimizar a função de custo. Ao seguir a direção oposta ao gradiente da função de custo, o algoritmo converge para um conjunto de parâmetros que otimiza o desempenho do modelo. Essa abordagem é essencial para a otimização eficiente de modelos em diversos cenários.
# <br>
# A padronização dos dados antes de aplicar algoritmos de Gradient Descent é essencial, pois garante que as variáveis tenham a mesma escala, permitindo uma convergência mais eficiente e estável durante o processo de otimização. Assim, sendo no código abaixo para alguém da divisão do dataframe em treino e teste, temos também a padronização dos dados.

# %%
X_train, X_test, y_train, y_test = train_test_split(cdf, target, test_size=0.25, random_state=42)
# Padronizar os dados
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# A função evaluate_model foi criada para avaliar o desempenho de um modelo, calculando as métricas R2 e RMSE. Essas métricas, essenciais na avaliação de modelos, oferecem percepções sobre a capacidade do modelo em explicar os dados e realizar previsões precisas. Esta função será utilizada em seguida para realizar avaliações de modelos.

# %%
# função para calcular o R2 e RMSE
def evaluate_model(X, y, theta):
    X_b = np.concatenate([np.ones((len(X), 1)), X], axis=1)
    y_pred = X_b.dot(theta)
    r2 = r2_score(y, y_pred)
    rmse = np.sqrt(mean_squared_error(y, y_pred))
    return r2, rmse

# %% [markdown]
# #### Batch Gradient Descent (BGD)

# %% [markdown]
# O código abaixo implementa o algoritmo de Gradiente Descendente em Batch (BGD) para otimizar iterativamente os parâmetros de um modelo. A função bgd recebe as variáveis independentes X e a variável dependente y, ajustando os parâmetros ao longo de iterações definidas. O BGD calcula os gradientes da função de custo em relação aos parâmetros utilizando todo o conjunto de dados de treino em cada iteração, ajustando os parâmetros na direção que minimiza a função de custo.

# %%
#implementação do algoritmo batch gradient descent
def bgd(X, y, n_iterations=1000, learning_rate=0.001, all_path=0):
    np.random.seed(42)
    thetas_path = []
    m = np.shape(X)[0]
    X_b = np.concatenate([np.ones((m, 1)), X], axis=1)
    thetas = np.random.randn(X_b.shape[1], 1)
    for i in range(n_iterations):
        gradients = 2/m * X_b.T.dot(X_b.dot(thetas) - y.reshape(-1, 1))
        thetas = thetas - learning_rate*gradients
        if all_path == 1:
            thetas_path.append(thetas)
        else:
            thetas_path = thetas
            
    return thetas_path

# %% [markdown]
# O  código abaixo realiza uma pesquisa exaustiva para encontrar a combinação ideal de hiperparâmetros para o algoritmo de Gradiente Descendente em Batch (BGD). Testando diferentes valores de taxa de aprendizado (learning_rates) e número de iterações (n_iterations), a pesquisa ajusta o modelo BGD para cada combinação e avalia o desempenho usando métricas como R2 e RMSE. O objetivo é identificar a combinação que resulta no menor RMSE, indicando a melhor precisão do modelo nos dados de teste. Os melhores hiperparâmetros e parâmetros do modelo são registrados e impressos ao final da pesquisa, proporcionando uma otimização eficiente do desempenho do modelo.

# %%
best_rmse = float("inf")
best_lr = None
best_iter = None
best_thetas = None
best_r2 = None

# Cria uma lista com valores para o learning_rate e pra o n_iterations
learning_rates = np.logspace(-6, -1, 20)
n_iterations = np.linspace(100, 1000, 10, dtype=int)

for lr in learning_rates:
    for n_iter in n_iterations:
        theta_bgd = bgd(X_train_scaled, y_train.values, n_iterations=n_iter, learning_rate=lr)
        r2, rmse = evaluate_model(X_test_scaled, y_test, theta_bgd)

        if rmse < best_rmse:
            best_rmse = rmse
            best_r2 = r2
            best_lr = lr
            best_iter = n_iter
            best_thetas = theta_bgd
            
print("Batch Gradient Descent (BGD)")
print(f"R2-Score: {best_r2}")
print(f"RMSE : {best_rmse}")

################################################################################
##################################### OUTPUT ###################################
#Batch Gradient Descent (BGD)
#R2-Score: 0.796543599120862
#RMSE : 4.266799145037127
# Out:
# Batch Gradient Descent (BGD)
# R2-Score: 0.796543599120862
# RMSE : 4.266799145037127

# %% [markdown]
# #### Stochastic Gradient Descent (SGD)

# %% [markdown]
# O código abaixo implementa o algoritmo de Gradiente Descendente Estocástico (SGD) para otimizar iterativamente os parâmetros de um modelo. A função sgd recebe as variáveis independentes X e a variável dependente y, além de hiperparâmetros como o número de épocas (n_epochs), t0, e t1. No SGD, um registo aleatório é usado em cada iteração, tornando o processo mais eficiente computacionalmente, e a taxa de aprendizado é adaptativa, ajustada de acordo com a função de programação de aprendizagem. Em resumo, o SGD é uma abordagem eficiente para otimizar modelos, contribuindo para a convergência eficiente do modelo, especialmente em grandes conjuntos de dados.

# %%
#implementação do algoritmo stochastic gradient descent
def sgd(X, y, n_epochs=50, t0=5, t1=50, all_path=0):
    m = np.shape(X)[0]
    X_b = np.concatenate([np.ones((m, 1)), X], axis=1)
    np.random.seed(42)
    thetas = np.random.randn(X_b.shape[1], 1)

    def learning_schedule(t):
        return t0 / (t + t1)

    thetas_path = []
    for epoch in range(n_epochs):
        for i in range(m):
            random_index = np.random.randint(m)
            xi = X_b[random_index:random_index+1]
            yi = y[random_index:random_index+1]
            gradients = 2 * np.transpose(xi) @ (xi.dot(thetas) - yi)
            eta = learning_schedule(epoch * m + i)
            thetas = thetas - eta * gradients

            if all_path == 1:
                thetas_path.append(thetas)
            else:
                thetas_path = thetas
                
    return thetas_path

# %% [markdown]
# O código abaixo realiza uma pesquisa para encontrar a combinação ideal de hiperparâmetros no contexto do algoritmo de Gradiente Descendente Estocástico (SGD). Utilizando diferentes valores de número de épocas (n_epochs), t0, e t1 em uma abordagem de pesquisa em grade, o código ajusta o modelo SGD para cada combinação e avalia o desempenho utilizando métricas como R2 e RMSE.
#
# As combinações possíveis são geradas usando o produto cartesiano das listas de valores especificadas para cada hiperparâmetro. A pesquisa visa identificar a combinação que resulta no menor RMSE, indicando a melhor precisão do modelo nos dados de teste. Os melhores hiperparâmetros e parâmetros do modelo são registrados e impressos ao final da pesquisa.

# %%
# Definir as listas para cada parâmetro
n_epochs_values = np.linspace(50, 150, 5, dtype=int)
t0_values = np.logspace(-3, 1, 5)
t1_values = np.logspace(-3, 1, 5)
best_thetas = None
best_r2 = None
best_rmse = float("inf")
best_combo = None

# Crie todas as combinações possíveis
combinations = list(product(n_epochs_values, t0_values, t1_values))

# Exiba as combinações
for combination in combinations:
    n_epochs, t0, t1 = combination
    theta_sgd = sgd(X_train_scaled, y_train.values, n_epochs=n_epochs, t0=t0, t1=t1)
    r2, rmse = evaluate_model(X_test_scaled, y_test, theta_sgd)
    
    if rmse < best_rmse:
        best_rmse = rmse
        best_r2 = r2
        best_thetas = theta_bgd
        best_combo = combination

print("Stochastic Gradient Descent (SGD)")
print(f"R2-Score: {best_r2}")
print(f"RMSE : {best_rmse}")

################################################################################
##################################### OUTPUT ###################################
#Stochastic Gradient Descent (SGD)
#R2-Score: 0.5418877875799721
#RMSE : 6.402542283397769
# Out:
# Stochastic Gradient Descent (SGD)
# R2-Score: 0.5418877875799721
# RMSE : 6.402542283397769

# %% [markdown]
# #### Mini-batch Gradient Descent (MGD)

# %% [markdown]
# O código abaixo implementa o algoritmo de Gradiente Descendente em Mini-Batch (MGD). A função mgd recebe as variáveis independentes X e a variável dependente y, além de hiperparâmetros como o número de iterações (n_iterations), o tamanho do mini-batch (minibatch_size), t0, e t1.
#
# No MGD, em cada iteração, um conjunto de amostras (mini-batch) é aleatoriamente selecionado do conjunto de dados total para calcular os gradientes. Isso combina as vantagens do BGD (utilizando mais informação por iteração) e do SGD (computacionalmente mais eficiente). A taxa de aprendizagem é ajustada dinamicamente ao longo das iterações.

# %%
#implementação do algoritmo Mini-batch Gradient Descent
def mgd(X, y, n_iterations=50, minibatch_size=20, t0=200, t1=1000, all_path=0):
    m = np.shape(X)[0]
    X_b = np.concatenate([np.ones((m, 1)), X], axis=1)
    np.random.seed(42)
    thetas = np.random.randn(X_b.shape[1], 1)

    def learning_schedule(t):
        return t0 / (t + t1)
    
    thetas_path = []
    t=0
    for epoch in range(n_iterations):
        shuffled_indices = np.random.permutation(m)
        X_b_shuffled = X_b[shuffled_indices]
        y_shuffled = y[shuffled_indices]
        for i in range(0, m, minibatch_size):
            t += 1
            xi = X_b_shuffled[i:i+minibatch_size]
            yi = y_shuffled[i:i+minibatch_size]
            
            minibatch_size_atual = xi.shape[0]
            
            gradients = 2/minibatch_size_atual * np.transpose(xi) @ (xi @ thetas - yi.reshape(-1, 1))
            eta = learning_schedule(t)
            thetas = thetas - eta * gradients
            
            if all_path == 1:
                thetas_path.append(thetas)
            else:
                thetas_path = thetas
                
    return thetas_path

# %% [markdown]
# O código abaixo realiza uma pesquisa para encontrar a combinação ideal de hiperparâmetros no contexto do algoritmo de Gradiente Descendente em Mini-Batch (MGD). Utilizando diferentes valores para o número de iterações (n_iterations), o tamanho do mini-batch (minibatch_size), t0, e t1 em uma abordagem de pesquisa em grade, o código ajusta o modelo MGD para cada combinação e avalia o desempenho utilizando métricas como R2 e RMSE.
#
# As combinações possíveis são geradas utilizando o produto cartesiano das listas de valores especificadas para cada hiperparâmetro. A pesquisa visa identificar a combinação que resulta no menor RMSE, indicando a melhor precisão do modelo nos dados de teste. Os melhores hiperparâmetros e parâmetros do modelo são registrados e impressos ao final da pesquisa.

# %%
#pesquisa em grade dos melhores parametros para o algoritmo mgd
# Lista para n_iterations
n_iterations_values = np.linspace(500, 2000, 4, dtype=int)
# Lista para minibatch_size
minibatch_size_values = np.linspace(32, 128, 3, dtype=int)
# Lista para t0 e t1
t0_values = np.logspace(-4, 0, 3)
t1_values = np.logspace(-2, 0, 3)

best_thetas = None
best_r2 = None
best_rmse = float("inf")
best_combo = None

# Crie todas as combinações possíveis
combinations = list(product(n_iterations_values, minibatch_size_values, t0_values, t1_values))

# Exiba as combinações
for combination in combinations:
    n_iterations, minibatch_size, t0, t1 = combination
    theta_mgd = mgd(X_train_scaled, y_train.values, n_iterations=n_iterations, 
                    minibatch_size=minibatch_size, t0=t0, t1=t1)
    r2, rmse = evaluate_model(X_test_scaled, y_test, theta_mgd)
    
    if rmse < best_rmse:
        best_rmse = rmse
        best_r2 = r2
        best_thetas = theta_mgd
        best_combo = combination

print("Mini-batch Gradient Descent (MGD)")
print(f"R2-Score: {best_r2}")
print(f"RMSE : {best_rmse}")

################################################################################
##################################### OUTPUT ###################################
#Mini-batch Gradient Descent (MGD)
#R2-Score: 0.7886116535148864
#RMSE : 4.349176586930092
# Out:
# Mini-batch Gradient Descent (MGD)
# R2-Score: 0.7886116535148864
# RMSE : 4.349176586930092

# %% [markdown]
# ## Regressão não linear

# %% [markdown]
# A função bestPolyRegression realiza uma pesquisa entre diferentes graus de polinômios para encontrar o melhor modelo de regressão polinomial em termos de menor RMSE (Root Mean Squared Error) nos dados de teste. Para cada grau de polinômio considerado, a função utiliza a classe PolynomialFeatures para criar características polinomiais apropriadas para a regressão. Em seguida, um modelo de regressão linear é treinado utilizando essas características.
#
# A métrica RMSE é calculada para o modelo treinado e comparada com o melhor RMSE registrado até o momento. Se o RMSE atual for menor, o modelo correspondente, a transformação polinomial utilizada e as métricas associadas são atualizadas como as melhores encontradas até o momento.
#
# Em resumo, essa função automatiza a escolha do melhor grau de polinômio para um modelo de regressão polinomial, facilitando a seleção do modelo que melhor se ajusta aos dados de teste.

# %%
#função para determinar qual o melhor modelo de regressão polinomial
#tendo como parametro de avaliação o menor RMSE
def bestPolyRegression(X, y, X_test, y_test):
    best_rmse = float('inf')
    best_model = None
    best_degree = None
    best_r2 = None
    for degree in range(2,7):
        poly_features = PolynomialFeatures(degree=degree, include_bias=False)
        X_poly = poly_features.fit_transform(X)
        X_test_poly = poly_features.transform(X_test)
        
        lin_reg = linear_model.LinearRegression()
        lin_reg.fit(X_poly, y)

        y_test_predict = lin_reg.predict(X_test_poly)
        y_predict = lin_reg.predict(X_poly)
        
        rmse = mean_squared_error(y_test, y_test_predict, squared=False)
        r2 = r2_score(y_test, y_test_predict)
        
        if rmse < best_rmse:
            best_rmse = rmse
            best_poly = poly_features
            best_model = lin_reg
            best_r2 = r2
            
    return best_model, best_poly, best_rmse, best_r2

# %% [markdown]
# O código abaixo utiliza a função bestPolyRegression para encontrar o melhor modelo de regressão polinomial, considerando diferentes graus de polinômios, com base nos dados de treinamento (X_train, y_train) e avaliando o desempenho nos dados de teste (X_test, y_test). Após a execução, são impressos o melhor valor de R² (Best R2), o menor RMSE (Best RMSE), e o grau do polinômio correspondente (Degree).
# <br>
# <br>
# <b>NOTA :</b> O modelo polinomial encontrado, poderá não ser o melhor possível, pois o calculo do modelo para graus mais elevado demorar muito tempo.

# %%
#obter o melhor modelo polinomial para os dados
model, poly, rmse, r2 = bestPolyRegression(X_train,y_train,X_test, y_test)

print("Best R2:",r2)
print("Best RMSE:", rmse)
print("Degree :",poly.degree)

################################################################################
##################################### OUTPUT ###################################
#Best R2: 0.8326252104555985
#Best RMSE: 3.870005146503624
#Degree : 6
# Out:
# Best R2: 0.8326252104555985
# Best RMSE: 3.870005146503624
# Degree : 6

# %% [markdown]
# ## Conclusão

# %% [markdown]
# Neste projeto, foram aplicados modelos de regressão para analisar a influência de variáveis como taxa de mortalidade, consumo de álcool e incidência de doenças sobre a esperança média de vida. A análise dos dados foi realizada utilizando a linguagem Python e bibliotecas especializadas, como scikit-learn.
#
# Os modelos foram avaliados com base em métricas padrão, como RMSE (Root Mean Squared Error) e R² (coeficiente de determinação). O RMSE fornece uma medida da diferença entre os valores observados e os valores previstos pelo modelo, enquanto o R² indica a proporção da variância na variável dependente que é previsível a partir das variáveis independentes.
#
# Com base nestas métricas, identificamos o modelo que apresentou o melhor equilíbrio entre precisão e capacidade de generalização. A análise do RMSE ajudou a identificar modelos com underfit (onde o modelo é muito simples e não capta a complexidade dos dados) ou overfit (onde o modelo é excessivamente complexo e se ajusta demais aos dados de treino).
#
# As implicações deste estudo são significativas para compreender os fatores que afetam a esperança média de vida. Os insights obtidos podem informar políticas de saúde pública e estratégias de intervenção para melhorar a qualidade de vida.
